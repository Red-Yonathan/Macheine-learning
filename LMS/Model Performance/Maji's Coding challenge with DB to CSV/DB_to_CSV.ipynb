# %%
import pandas as pd
import sqlite3

# %%
conn = sqlite3.connect("Maji_Ndogo_farm_survey_small.db")
tables= pd.read_sql_query("SELECT name FROM sqlite_master WHERE type ='table'",conn) #-?

tables.name
# Out:
# 0         geographic_features
# 1            weather_features
# 2      soil_and_crop_features
# 3    farm_management_features
# Name: name, dtype: object

# %%
data = {}
for i in tables.name:
    data[i] = pd.read_sql_query(f"SELECT * From {i}",conn) # use f stirng whenever you wanna use a varibale int he SQL query
data
# Out:
# {'geographic_features':       Field_ID  Elevation   Latitude  Longitude        Location      Slope
#  0        40734  786.05580  -7.389911  -7.556202    Rural_Akatsi  14.795113
#  1        30629  674.33410  -7.736849  -1.051539    Rural_Sokoto  11.374611
#  2        39924  826.53390  -9.926616   0.115156    Rural_Sokoto  11.339692
#  3         5754  574.94617  -2.420131  -6.592215  Rural_Kilimani   7.109855
#  4        14146  886.35300  -3.055434  -7.952609  Rural_Kilimani  55.007656
#  ...        ...        ...        ...        ...             ...        ...
#  5649     11472  681.36145  -7.358371  -6.254369    Rural_Akatsi  16.213196
#  5650     19660  667.02120  -3.154559  -4.475046  Rural_Kilimani   2.397553
#  5651     41296  670.77900 -14.472861  -6.110221   Rural_Hawassa   7.636470
#  5652     33090  429.48840 -14.653089  -6.984116   Rural_Hawassa  13.944720
#  5653      8375  763.09030  -4.317028  -6.344461  Rural_Kilimani  35.189430
#
#  [5654 rows x 6 columns],
# ...

# %%
# for i in data.keys():
#     if 'Crop_type' == data[i].columns
data['farm_management_features']
# Out:
#       Field_ID  Pollution_level  Plot_size  Crop_type Annual_yield  \
# 0        40734     8.526684e-02        1.3   0.751354      cassava
# 1        30629     3.996838e-01        2.2   1.069865      cassava
# 2        39924     3.580286e-01        3.4   2.208801          tea
# 3         5754     2.866871e-01        2.4   1.277635      cassava
# 4        14146     4.319027e-02        1.5   0.832614        wheat
# ...        ...              ...        ...        ...          ...
# 5649     11472     3.286828e-01        1.1   0.609930       potato
# 5650     19660     1.602583e-01        8.7   3.812289        maize
# 5651     41296     8.221326e-09        2.1   1.681629          tea
# 5652     33090     6.917245e-10        1.3   0.659874      cassava
# 5653      8375     2.612715e-01        0.5   0.226532        wheat
#
#       Standard_yield
# 0           0.577964
# 1           0.486302
# 2           0.649647
# 3           0.532348
# 4           0.555076
# ...              ...
# ...

# %%
all_data = pd.concat(data.values(),ignore_index=True)
all_data
# Out:
#        Field_ID  Elevation  Latitude  Longitude        Location      Slope  \
# 0         40734  786.05580 -7.389911  -7.556202    Rural_Akatsi  14.795113
# 1         30629  674.33410 -7.736849  -1.051539    Rural_Sokoto  11.374611
# 2         39924  826.53390 -9.926616   0.115156    Rural_Sokoto  11.339692
# 3          5754  574.94617 -2.420131  -6.592215  Rural_Kilimani   7.109855
# 4         14146  886.35300 -3.055434  -7.952609  Rural_Kilimani  55.007656
# ...         ...        ...       ...        ...             ...        ...
# 22611     11472        NaN       NaN        NaN             NaN        NaN
# 22612     19660        NaN       NaN        NaN             NaN        NaN
# 22613     41296        NaN       NaN        NaN             NaN        NaN
# 22614     33090        NaN       NaN        NaN             NaN        NaN
# 22615      8375        NaN       NaN        NaN             NaN        NaN
#
#        Rainfall  Min_temperature_C  Max_temperature_C  Ave_temps  \
# ...

# %%
data['crop']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 data['crop']
#
# KeyError: 'crop'

# %%
# all_data.to_csv("Maji_Ndogo_farm_survey_small.csv")
conn.close()

# %%
df = pd.read_csv("Maji_Ndogo_farm_survey_small.csv")
df.head()
# Out:
#    Unnamed: 0  Field_ID  Elevation  Latitude  Longitude        Location  \
# 0           0     40734  786.05580 -7.389911  -7.556202    Rural_Akatsi
# 1           1     30629  674.33410 -7.736849  -1.051539    Rural_Sokoto
# 2           2     39924  826.53390 -9.926616   0.115156    Rural_Sokoto
# 3           3      5754  574.94617 -2.420131  -6.592215  Rural_Kilimani
# 4           4     14146  886.35300 -3.055434  -7.952609  Rural_Kilimani
#
#        Slope  Rainfall  Min_temperature_C  Max_temperature_C  Ave_temps  \
# 0  14.795113       NaN                NaN                NaN        NaN
# 1  11.374611       NaN                NaN                NaN        NaN
# 2  11.339692       NaN                NaN                NaN        NaN
# 3   7.109855       NaN                NaN                NaN        NaN
# 4  55.007656       NaN                NaN                NaN        NaN
#
#    Soil_fertility Soil_type  pH  Pollution_level  Plot_size  Crop_type  \
# ...
